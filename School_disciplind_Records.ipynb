# %%
import pandas as pd

# %%
school_discplined_df = pd.read_csv("School_disciplined_report_illegal_substance_21-22.csv")

# %%
school_discplined_df.head(10)
# Out:
#                                        District Name  District Code Students  \
# 0                                           Abington          10000    2,246
# 1  Academy Of the Pacific Rim Charter Public (Dis...        4120000      534
# 2                                   Acton-Boxborough        6000000    5,342
# 3                                           Acushnet          30000      960
# 4  Advanced Math and Science Academy Charter (Dis...        4300000      981
# 5                                             Agawam          50000    3,635
# 6             Alma del Mar Charter School (District)        4090000      978
# 7                                           Amesbury          70000    1,894
# 8                                     Amherst-Pelham        6050000    1,308
# 9                                            Andover          90000    5,612
#
#   Students Disciplined  % In-School Suspension  % Out-of-School Suspension  \
# ...

# %%
school_discplined_df.fillna(value=0, inplace=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 import geopandas as gpd
#       3 # Load the GeoJSON file into a GeoDataFrame
# ----> 4 districts_gdf = gpd.read_file("https://opendata.arcgis.com/datasets/fdcdcbf3b3a1453f9b9d19b5b169c5f5_0.geojson")
#       6 # Filter the GeoDataFrame to get the polygon for District 4
#       7 district_4_gdf = districts_gdf[districts_gdf["DISTRICT"] == "4"]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\geopandas\io\file.py:248, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     246 from_bytes = False
#     247 if _is_url(filename):
# --> 248     req = _urlopen(filename)
#     249     path_or_bytes = req.read()
#     250     from_bytes = True
#
# ...
