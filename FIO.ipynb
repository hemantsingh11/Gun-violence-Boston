# %%
import pandas as pd

# %%
fieldContact_df = pd.read_csv("fio-records-2022-mark43-fieldcontact-table.csv")

# %%
fieldContactName_df = pd.read_csv("fio-records-2022-mark43-fieldcontact_name-table.csv")

# %%
fieldContact_df.head()
# Out:
#        fc_num         contact_date  contact_officer      contact_officer_name  \
# 0  FC22000008  2022-01-01 00:00:00           151206      WATTY-NILES, CREFTON
# 1  FC22000001  2022-01-01 02:30:00           153132  VILLEGAS-HOAG, STEPHANIE
# 2  FC22000004  2022-01-01 09:29:00           148290           PARHAM, ANTHONY
# 3  FC22000003  2022-01-01 10:16:00           162319             Uhrig, Robert
# 4  FC22000005  2022-01-01 10:29:00           100417             FLYNN, THOMAS
#
#    supervisor      supervisor_name       street          city state   zip  \
# 0       11586  CHRISTOPHER CARROLL    ALBANY ST        BOSTON    MA  2118
# 1       11212     MICHAEL MCCARTHY          NaN        BOSTON    MA  2122
# 2       10845          JAMES MOORE   BRIARCLIFF      MATTAPAN    MA  2126
# 3        9266       STEVEN CICCOLO  E EIGHTH ST  SOUTH BOSTON    MA  2127
# 4       11212     MICHAEL MCCARTHY  ROBINSON ST    DORCHESTER    MA  2122
#
#    ...                  basis vehicle_year vehicle_state  vehicle_model  \
# 0  ...  Reasonable Suspicion           NaN           NaN            NaN
# 1  ...         Probable Cause       2008.0            MA         Taurus
# 2  ...              Encounter          NaN           NaN            NaN
# 3  ...  Reasonable Suspicion           NaN           NaN            NaN
# 4  ...         Probable Cause          NaN           NaN            NaN
#
#   vehicle_color  vehicle_style               vehicle_type key_situations  \
# 0           NaN            NaN                        NaN            NaN
# 1         Brown  4 Door, Sedan  Passenger Car/ Automobile            NaN
# 2           NaN            NaN                        NaN            NaN
# 3           NaN            NaN                        NaN            NaN
# 4           NaN            NaN                        NaN            NaN
#
#                                       contact_reason  weather
# 0  01/01/2022 11:40 PM\n\nOfficers responded to a...      NaN
# 1  About 02:30am, Officers assisted State Police ...      NaN
# 2  About 10:00AM, Saturday 1/1/21 Officers respon...      NaN
# 3  About 10:16am on Saturday, 01/01/22, Officers ...      NaN
# 4  Officers responded to a radio call for a B&E t...      NaN
#
# [5 rows x 22 columns]

# %%
fieldContactName_df.head()
# Out:
#      person_id                 contact_date      fc_num     sex   race   age  \
# 0  30750626451  2022-01-01 00:00:00.0000000  FC22000008    Male  Black   NaN
# 1  30745256091  2022-01-01 02:30:00.0000000  FC22000001    Male  Black  25.0
# 2  30747685932  2022-01-01 09:29:00.0000000  FC22000004    Male  Black  39.0
# 3  30747687157  2022-01-01 09:29:00.0000000  FC22000004  Female  Black  35.0
# 4  30747589299  2022-01-01 10:16:00.0000000  FC22000003    Male  White  54.0
#
#     build       hair_style               ethnicity     skin_tone  deceased  \
# 0     NaN              NaN                     NaN           NaN         0
# 1    Thin            Short  Not of Hispanic Origin         Brown         0
# 2  Medium  Bald or Balding  Not of Hispanic Origin  Medium Brown         0
# 3     NaN              NaN  Not of Hispanic Origin           NaN         0
# 4  Medium              NaN  Not of Hispanic Origin           NaN         0
#
#               license_type license_state  was_frisked
# 0                      NaN           NaN          0.0
# 1  Personal Driver License            MA          1.0
# 2                  Class D            MA          1.0
# 3                  Class D            MA          NaN
# 4                      NaN           NaN          0.0

# %%
print(fieldContact_df.shape)
print(fieldContactName_df.shape)
# Out:
# (5278, 22)
# (9408, 14)

# %%
print(len(fieldContact_df['fc_num'].unique()))
print(len(fieldContactName_df['fc_num'].unique()))
# Out:
# 5124
# 5254

# %%
# Merging both field contact and field contact name dataframes
fio_df = pd.merge(fieldContact_df, fieldContactName_df, how='inner', left_on = 'fc_num', right_on = 'fc_num')

# %%
fio_df.shape
# Out:
# (9458, 35)

# %%
fio_df.head(20)
# Out:
#         fc_num       contact_date_x  contact_officer  \
# 0   FC22000008  2022-01-01 00:00:00           151206
# 1   FC22000001  2022-01-01 02:30:00           153132
# 2   FC22000004  2022-01-01 09:29:00           148290
# 3   FC22000004  2022-01-01 09:29:00           148290
# 4   FC22000003  2022-01-01 10:16:00           162319
# 5   FC22000003  2022-01-01 10:16:00           162319
# 6   FC22000005  2022-01-01 10:29:00           100417
# 7   FC22000005  2022-01-01 10:29:00           100417
# 8   FC22000006  2022-01-01 11:50:00           148310
# 9   FC22000007  2022-01-01 19:35:00            90495
# 10  FC22000007  2022-01-01 19:35:00            90495
# 11  FC22000007  2022-01-01 19:35:00            90495
# 12  FC22000009  2022-01-01 23:59:00           157666
# 13  FC22000009  2022-01-01 23:59:00           157666
# 14  FC22000016  2022-01-02 01:06:00           148281
# 15  FC22000016  2022-01-02 01:06:00           148281
# 16  FC22000010  2022-01-02 01:15:00           153081
# 17  FC22000012  2022-01-02 09:45:00           111241
# 18  FC22000026  2022-01-02 14:20:00           140282
# 19  FC22000014  2022-01-02 17:00:00           162930
#
#         contact_officer_name  supervisor      supervisor_name          street  \
# 0       WATTY-NILES, CREFTON       11586  CHRISTOPHER CARROLL       ALBANY ST
# 1   VILLEGAS-HOAG, STEPHANIE       11212     MICHAEL MCCARTHY             NaN
# 2            PARHAM, ANTHONY       10845          JAMES MOORE      BRIARCLIFF
# 3            PARHAM, ANTHONY       10845          JAMES MOORE      BRIARCLIFF
# 4              Uhrig, Robert        9266       STEVEN CICCOLO     E EIGHTH ST
# 5              Uhrig, Robert        9266       STEVEN CICCOLO     E EIGHTH ST
# 6              FLYNN, THOMAS       11212     MICHAEL MCCARTHY     ROBINSON ST
# 7              FLYNN, THOMAS       11212     MICHAEL MCCARTHY     ROBINSON ST
# 8           VERDERICO, JAMES        9021       THOMAS HOPKINS       ALBANY ST
# 9            FLAVEN, MICHAEL       11827       MICHAEL MYLETT  GEORGETOWNE DR
# 10           FLAVEN, MICHAEL       11827       MICHAEL MYLETT  GEORGETOWNE DR
# 11           FLAVEN, MICHAEL       11827       MICHAEL MYLETT  GEORGETOWNE DR
# 12              MEJIA, KAREN      131216      ZACHARY CROSSEN   COMMERCIAL ST
# 13              MEJIA, KAREN      131216      ZACHARY CROSSEN   COMMERCIAL ST
# 14     KERRIGAN, CHRISTOPHER        9378       THOMAS O'LEARY   WASHINGTON ST
# 15     KERRIGAN, CHRISTOPHER        9378       THOMAS O'LEARY   WASHINGTON ST
# 16          LEWIS, JOHNATHAN       10845          JAMES MOORE    GREENWOOD ST
# 17       MUSTACCHIO, MICHAEL      131216      ZACHARY CROSSEN             NaN
# 18        ADAMS, CHRISTOPHER       12120    EDIBERTO FIGUEROA             NaN
# 19       McCullough, Matthew      131216      ZACHARY CROSSEN             NaN
#
#             city state   zip  ...     race   age   build       hair_style  \
# 0         BOSTON    MA  2118  ...    Black   NaN     NaN              NaN
# 1         BOSTON    MA  2122  ...    Black  25.0    Thin            Short
# 2       MATTAPAN    MA  2126  ...    Black  39.0  Medium  Bald or Balding
# 3       MATTAPAN    MA  2126  ...    Black  35.0     NaN              NaN
# 4   SOUTH BOSTON    MA  2127  ...    White  54.0  Medium              NaN
# 5   SOUTH BOSTON    MA  2127  ...    White  44.0     NaN              NaN
# 6     DORCHESTER    MA  2122  ...    White  31.0     NaN              NaN
# 7     DORCHESTER    MA  2122  ...    Black  35.0  Medium            Short
# 8         BOSTON    MA  2118  ...    White  39.0  Medium            Short
# 9      HYDE PARK    MA  2136  ...    Black  40.0     NaN              NaN
# 10     HYDE PARK    MA  2136  ...    Black  41.0     NaN              NaN
# 11     HYDE PARK    MA  2136  ...    Black  38.0     NaN              NaN
# 12        BOSTON    MA  2109  ...    White  31.0     NaN              NaN
# 13        BOSTON    MA  2109  ...    White  28.0     NaN              NaN
# 14       ROXBURY    MA  2119  ...    Black  42.0     NaN              NaN
# 15       ROXBURY    MA  2119  ...    Black  48.0     NaN              NaN
# 16    DORCHESTER    MA  2121  ...  Unknown   NaN     NaN              NaN
# 17        BOSTON    MA  2114  ...    White  67.0    Thin              NaN
# 18        BOSTON    MA  2119  ...    Black  56.0  Medium            Short
# 19        BOSTON    MA  2111  ...    Black  24.0    Thin            Short
#
#                  ethnicity     skin_tone deceased  \
# 0                      NaN           NaN        0
# 1   Not of Hispanic Origin         Brown        0
# 2   Not of Hispanic Origin  Medium Brown        0
# 3   Not of Hispanic Origin           NaN        0
# 4   Not of Hispanic Origin           NaN        0
# 5                  Unknown           NaN        0
# 6   Not of Hispanic Origin           NaN        0
# 7                      NaN  Medium Brown        0
# 8   Not of Hispanic Origin           NaN        0
# 9   Not of Hispanic Origin           NaN        0
# 10  Not of Hispanic Origin           NaN        0
# 11  Not of Hispanic Origin           NaN        0
# 12  Not of Hispanic Origin           NaN        0
# 13         Hispanic Origin           NaN        0
# 14  Not of Hispanic Origin           NaN        0
# 15  Not of Hispanic Origin           NaN        0
# 16                     NaN           NaN        0
# 17  Not of Hispanic Origin           NaN        0
# 18                 Unknown  Medium Brown        0
# 19         Hispanic Origin  Medium Brown        0
#
#                                    license_type license_state  was_frisked
# 0                                           NaN           NaN          0.0
# 1                       Personal Driver License            MA          1.0
# 2                                       Class D            MA          1.0
# 3                                       Class D            MA          NaN
# 4                                           NaN           NaN          0.0
# 5   ID Only - Never had Personal Driver License            MA          0.0
# 6                                       Class D            MA          0.0
# 7                                       Class D            MA          0.0
# 8                                       Class D            MA          0.0
# 9                                       Class D            MA          1.0
# 10                                          NaN            MA          0.0
# 11                                          NaN           NaN          0.0
# 12                                          NaN            PA          0.0
# 13                                          NaN            PA          0.0
# 14                                      Class D            MA          NaN
# 15                                          NaN           NaN          0.0
# 16                                          NaN           NaN          0.0
# 17                                      Class D            MA          0.0
# 18                                          NaN            MA          0.0
# 19                           Instruction Permit            MA          0.0
#
# [20 rows x 35 columns]

# %%
# city council 
cityCouncilDistrict_D4_zip = [2121, 2122, 2124, 2125, 2126, 2131 ]
policeDistrict_D4_zip = [2116, 2115, 2215, 2120,  2116, 2114, 2111, 2113]

# %%
# Filter the rows based on zip_district_4
fio_policeDistrict_D4_df = fio_df[fio_df['zip'].isin(policeDistrict_D4_zip)]
fio_cityCouncilDistrict_D4_df = fio_df[fio_df['zip'].isin(cityCouncilDistrict_D4_zip)]

# %%
print(fio_policeDistrict_D4_df.shape)
print(fio_cityCouncilDistrict_D4_df.shape)
# Out:
# (1278, 35)
# (4101, 35)

# %%
fio_cityCouncilDistrict_D4_df.head(20)
# Out:
#         fc_num       contact_date_x  contact_officer  \
# 1   FC22000001  2022-01-01 02:30:00           153132
# 2   FC22000004  2022-01-01 09:29:00           148290
# 3   FC22000004  2022-01-01 09:29:00           148290
# 6   FC22000005  2022-01-01 10:29:00           100417
# 7   FC22000005  2022-01-01 10:29:00           100417
# 16  FC22000010  2022-01-02 01:15:00           153081
# 20  FC22000015  2022-01-02 18:35:00           105619
# 21  FC22000015  2022-01-02 18:35:00           105619
# 22  FC22000015  2022-01-02 18:35:00           105619
# 23  FC22000015  2022-01-02 18:35:00           105619
# 24  FC22000021  2022-01-02 22:15:00           124390
# 25  FC22000021  2022-01-02 22:15:00           124390
# 26  FC22000021  2022-01-02 22:15:00           124390
# 30  FC22000020  2022-01-03 12:20:00           128383
# 31  FC22000020  2022-01-03 12:20:00           128383
# 32  FC22000022  2022-01-03 17:03:00           157676
# 33  FC22000023  2022-01-03 18:21:00           126478
# 34  FC22000028  2022-01-04 20:35:00            99776
# 35  FC22000029  2022-01-04 20:39:00           153083
# 36  FC22000029  2022-01-04 20:39:00           153083
#
#         contact_officer_name  supervisor   supervisor_name           street  \
# 1   VILLEGAS-HOAG, STEPHANIE       11212  MICHAEL MCCARTHY              NaN
# 2            PARHAM, ANTHONY       10845       JAMES MOORE       BRIARCLIFF
# 3            PARHAM, ANTHONY       10845       JAMES MOORE       BRIARCLIFF
# 6              FLYNN, THOMAS       11212  MICHAEL MCCARTHY      ROBINSON ST
# 7              FLYNN, THOMAS       11212  MICHAEL MCCARTHY      ROBINSON ST
# 16          LEWIS, JOHNATHAN       10845       JAMES MOORE     GREENWOOD ST
# 20             LOPES, SAMORA       10092     DANIEL TRACEY              NaN
# 21             LOPES, SAMORA       10092     DANIEL TRACEY              NaN
# 22             LOPES, SAMORA       10092     DANIEL TRACEY              NaN
# 23             LOPES, SAMORA       10092     DANIEL TRACEY              NaN
# 24          COYNE, CHRISTIAN        9378    THOMAS O'LEARY              NaN
# 25          COYNE, CHRISTIAN        9378    THOMAS O'LEARY              NaN
# 26          COYNE, CHRISTIAN        9378    THOMAS O'LEARY              NaN
# 30         O'CONNOR, MATTHEW       99722      JOHN BURROWS    BLUE HILL AVE
# 31         O'CONNOR, MATTHEW       99722      JOHN BURROWS    BLUE HILL AVE
# 32    PANZAVECCHIA, STEFANIA       99722      JOHN BURROWS  WESTVIEW STREET
# 33          BELGRAVE, FABIAN        9266    STEVEN CICCOLO      ALLSTATE RD
# 34        LEVICHEV, VLADIMIR       11180  PATRICK MORRISON       KIMBALL ST
# 35      HARRINGTON, BRIAN, F       10845       JAMES MOORE    BLUE HILL AVE
# 36      HARRINGTON, BRIAN, F       10845       JAMES MOORE    BLUE HILL AVE
#
#           city state   zip  ...     race   age   build       hair_style  \
# 1       BOSTON    MA  2122  ...    Black  25.0    Thin            Short
# 2     MATTAPAN    MA  2126  ...    Black  39.0  Medium  Bald or Balding
# 3     MATTAPAN    MA  2126  ...    Black  35.0     NaN              NaN
# 6   DORCHESTER    MA  2122  ...    White  31.0     NaN              NaN
# 7   DORCHESTER    MA  2122  ...    Black  35.0  Medium            Short
# 16  DORCHESTER    MA  2121  ...  Unknown   NaN     NaN              NaN
# 20      BOSTON    MA  2124  ...    Black  20.0    Thin              NaN
# 21      BOSTON    MA  2124  ...    White  18.0    Thin              NaN
# 22      BOSTON    MA  2124  ...    Black  18.0     NaN              NaN
# 23      BOSTON    MA  2124  ...    White  21.0  Medium              NaN
# 24      BOSTON    MA  2121  ...    Black  14.0     NaN              NaN
# 25      BOSTON    MA  2121  ...    White  15.0     NaN              NaN
# 26      BOSTON    MA  2121  ...    Black  18.0     NaN              NaN
# 30  DORCHESTER    MA  2124  ...    Black  17.0  Medium            Short
# 31  DORCHESTER    MA  2124  ...    Black  20.0     NaN              NaN
# 32      BOSTON    MA  2124  ...    Black  23.0    Thin       Dreadlocks
# 33  DORCHESTER    MA  2125  ...    White  35.0    Thin            Short
# 34  DORCHESTER    MA  2122  ...    Black  33.0  Medium              NaN
# 35      BOSTON    MA  2125  ...    Other  41.0     NaN              NaN
# 36      BOSTON    MA  2125  ...    Other  41.0     NaN              NaN
#
#                  ethnicity     skin_tone deceased             license_type  \
# 1   Not of Hispanic Origin         Brown        0  Personal Driver License
# 2   Not of Hispanic Origin  Medium Brown        0                  Class D
# 3   Not of Hispanic Origin           NaN        0                  Class D
# 6   Not of Hispanic Origin           NaN        0                  Class D
# 7                      NaN  Medium Brown        0                  Class D
# 16                     NaN           NaN        0                      NaN
# 20         Hispanic Origin           NaN        0                      NaN
# 21         Hispanic Origin           NaN        0                      NaN
# 22  Not of Hispanic Origin           NaN        0                      NaN
# 23         Hispanic Origin           NaN        0                     None
# 24                     NaN           NaN        0                      NaN
# 25         Hispanic Origin           NaN        0                      NaN
# 26  Not of Hispanic Origin           NaN        0                  Class D
# 30  Not of Hispanic Origin          Dark        0                     None
# 31                 Unknown           NaN        0     Other: Class 10 - RI
# 32                     NaN  Medium Brown        0                  Class D
# 33  Not of Hispanic Origin        Medium        0                      NaN
# 34  Not of Hispanic Origin           NaN        0                      NaN
# 35         Hispanic Origin           NaN        0                  Class D
# 36         Hispanic Origin           NaN        0                  Class D
#
#    license_state  was_frisked
# 1             MA          1.0
# 2             MA          1.0
# 3             MA          NaN
# 6             MA          0.0
# 7             MA          0.0
# 16           NaN          0.0
# 20            MA          1.0
# 21            MA          1.0
# 22            MA          1.0
# 23            MA          1.0
# 24           NaN          1.0
# 25           NaN          1.0
# 26            MA          1.0
# 30            MA          1.0
# 31            RI          1.0
# 32            MA          0.0
# 33            MA          1.0
# 34            MA          0.0
# 35            MA          NaN
# 36            MA          NaN
#
# [20 rows x 35 columns]
